# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
if not ".." in sys.path:
    sys.path.append("..")

# %%
from playground_utils import PlaygroundExport, PlaygroundViewer

# %%
job_name = "test-export-new2"
input_dir = "../example-dataset/"
tags_to_labels = {"test": "object", "change": "change"}
labels_color = {"object": (0, 0, 255), "change": (0, 255, 0)}

# %%
plx = PlaygroundExport(input_dir, job_name)
print(plx)
# Out:
# Findind dataset files: 100%|██████████| 1/1 [00:00<00:00, 565.42it/s]
#  ../example-dataset/ - test-export-new2
#  2 Zones 11 Tiles
# Dataset fb9a04fc-9f87-481d-a4df-ae5fec5e2be1: 2 zones - 11 tiles

# %%
plv = PlaygroundViewer(plx, tags_to_labels, labels_color)

# %%
plv.check_random_tiles(4)
