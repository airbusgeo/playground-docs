# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from playground_utils import PlaygroundViewer

# %%
job_name = "change-detection-128"
input_dir = "/mnt/data_ship/raw/change-detection-128/"
tags_to_labels = {"Groundtruth":"change","Ground Truth":"change"}
labels_color = {"change": (0,255,0)}

# %%
plv = PlaygroundViewer(job_name,input_dir,tags_to_labels,labels_color)
# Out:
# Parsing Playground Export
# Found 3 datasets in /mnt/data_ship/raw/change-detection-128//change-detection-128
# Found 17 zones in /mnt/data_ship/raw/change-detection-128//change-detection-128
# Found 13430 tiles in /mnt/data_ship/raw/change-detection-128//change-detection-128

# %%
plv.check_random_tiles(12)
